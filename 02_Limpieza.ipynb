# %%
import pandas as pd
from pandas import json_normalize
import json
import numpy as np

pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ElProfeAlejo/Bootcamp_Databases/main/traffic_site.csv')
df.head()
# Out:
#   channelGrouping      date  \
# 0  Organic Search  20160902
# 1  Organic Search  20160902
# 2      Affiliates  20160902
# 3  Organic Search  20160902
# 4  Organic Search  20160902
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...  9674781571160116268
# 1  {"browser": "Chrome", "browserVersion": "not a...  8590648239310839049
# 2  {"browser": "Chrome", "browserVersion": "not a...  9772828344252850532
# 3  {"browser": "Safari", "browserVersion": "not a...  1350700416054916432
# 4  {"browser": "Safari", "browserVersion": "not a...  1350700416054916432
#
#                                           geoNetwork  \
# 0  {"continent": "Asia", "subContinent": "Southea...
# 1  {"continent": "Europe", "subContinent": "Easte...
# 2  {"continent": "Americas", "subContinent": "Sou...
# 3  {"continent": "Americas", "subContinent": "Nor...
# 4  {"continent": "Americas", "subContinent": "Nor...
#
#                         sessionId  socialEngagementType  \
# 0  9674781571160116268_1472804607  Not Socially Engaged
# 1  8590648239310839049_1472835928  Not Socially Engaged
# 2  9772828344252850532_1472856802  Not Socially Engaged
# 3  1350700416054916432_1472879649  Not Socially Engaged
# 4  1350700416054916432_1472829671  Not Socially Engaged
#
#                                               totals  \
# 0  {"visits": "1", "hits": "1", "pageviews": "1",...
# 1  {"visits": "1", "hits": "1", "pageviews": "1",...
# 2  {"visits": "1", "hits": "1", "pageviews": "1",...
# 3  {"visits": "1", "hits": "1", "pageviews": "1",...
# 4  {"visits": "1", "hits": "5", "pageviews": "4",...
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"campaign": "(not set)", "source": "google", ...  1472804607            1
# 1  {"campaign": "(not set)", "source": "google", ...  1472835928            1
# 2  {"campaign": "Data Share Promo", "source": "Pa...  1472856802            1
# 3  {"campaign": "(not set)", "source": "google", ...  1472879649            2
# 4  {"campaign": "(not set)", "source": "google", ...  1472829671            1
#
#    visitStartTime
# 0      1472804607
# 1      1472835928
# 2      1472856802
# 3      1472879649
# 4      1472829671

# %%
df.shape
# Out:
# (12283, 12)

# %%
# device = df["device"].tolist()
# # Convertir cada cadena JSON a un diccionario y almacenarlo en una lista
# data = [json.loads(json_data) for json_data in device]

# # Normalizar los datos
# df = pd.json_normalize(data)

# %%
diccionarios = ['device','geoNetwork','trafficSource','totals']

df_traffic = df[diccionarios]

# %%
# Iteramos sobre las columnas del diccionario
for columna in diccionarios:
    # Convertimos cada línea de la columna a un diccionario JSON y luego creamos un DataFrame con ellas
    df_nuevo = pd.DataFrame([json.loads(linea) for linea in df_traffic[columna]])
    # Unimos el nuevo DataFrame con el DataFrame principal df_traffic
    df_traffic = df_traffic.join(df_nuevo)

# %%
# Eliminar columnas
columnas_a_eliminar = ['device', 'geoNetwork', 'trafficSource', 'totals']
df_traffic = df_traffic.drop(columnas_a_eliminar, axis=1)

# %%
df_traffic.head()
# Out:
#   browser                 browserVersion                    browserSize  \
# 0  Chrome  not available in demo dataset  not available in demo dataset
# 1  Chrome  not available in demo dataset  not available in demo dataset
# 2  Chrome  not available in demo dataset  not available in demo dataset
# 3  Safari  not available in demo dataset  not available in demo dataset
# 4  Safari  not available in demo dataset  not available in demo dataset
#
#   operatingSystem         operatingSystemVersion  isMobile  \
# 0         Windows  not available in demo dataset     False
# 1       Macintosh  not available in demo dataset     False
# 2       Macintosh  not available in demo dataset     False
# 3             iOS  not available in demo dataset      True
# 4             iOS  not available in demo dataset      True
#
#             mobileDeviceBranding              mobileDeviceModel  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#              mobileInputSelector               mobileDeviceInfo  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#        mobileDeviceMarketingName                   flashVersion  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                         language                   screenColors  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                 screenResolution deviceCategory continent      subContinent  \
# 0  not available in demo dataset        desktop      Asia    Southeast Asia
# 1  not available in demo dataset        desktop    Europe    Eastern Europe
# 2  not available in demo dataset        desktop  Americas     South America
# 3  not available in demo dataset         mobile  Americas  Northern America
# 4  not available in demo dataset         mobile  Americas  Northern America
#
#          country                         region  \
# 0      Singapore                      (not set)
# 1         Poland  not available in demo dataset
# 2      Argentina                   Buenos Aires
# 3  United States  not available in demo dataset
# 4  United States  not available in demo dataset
#
#                            metro                           city  \
# 0                      (not set)                      Singapore
# 1  not available in demo dataset  not available in demo dataset
# 2                      (not set)                   Buenos Aires
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                           cityId       networkDomain  \
# 0  not available in demo dataset     unknown.unknown
# 1  not available in demo dataset            tpnet.pl
# 2  not available in demo dataset  phonevision.com.ar
# 3  not available in demo dataset         comcast.net
# 4  not available in demo dataset             att.net
#
#                         latitude                      longitude  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                  networkLocation          campaign    source     medium  \
# 0  not available in demo dataset         (not set)    google    organic
# 1  not available in demo dataset         (not set)    google    organic
# 2  not available in demo dataset  Data Share Promo  Partners  affiliate
# 3  not available in demo dataset         (not set)    google    organic
# 4  not available in demo dataset         (not set)    google    organic
#
#           keyword                                   adwordsClickInfo  \
# 0  (not provided)  {'criteriaParameters': 'not available in demo ...
# 1  (not provided)  {'criteriaParameters': 'not available in demo ...
# 2             NaN  {'criteriaParameters': 'not available in demo ...
# 3  (not provided)  {'criteriaParameters': 'not available in demo ...
# 4  (not provided)  {'criteriaParameters': 'not available in demo ...
#
#   isTrueDirect referralPath adContent campaignCode visits hits pageviews  \
# 0          NaN          NaN       NaN          NaN      1    1         1
# 1          NaN          NaN       NaN          NaN      1    1         1
# 2          NaN          NaN       NaN          NaN      1    1         1
# 3         True          NaN       NaN          NaN      1    1         1
# 4          NaN          NaN       NaN          NaN      1    5         4
#
#   bounces newVisits transactionRevenue
# 0       1         1                NaN
# 1       1         1                NaN
# 2       1         1                NaN
# 3       1       NaN                NaN
# 4     NaN         1                NaN

# %%
df_traffic['bounces'].value_counts()
# Out:
# 1    6172
# Name: bounces, dtype: int64

# %%
# columnas a conservar
columnas_deseadas = ['browser', 'operatingSystem', 'isMobile', 'deviceCategory', 'subContinent',
                     'source', 'medium', 'isTrueDirect', 'hits', 'pageviews','bounces', 'newVisits', 'transactionRevenue']

df_traffic = df_traffic[columnas_deseadas].copy()

# %%
df_traffic.head()
# Out:
#   browser operatingSystem  isMobile deviceCategory      subContinent  \
# 0  Chrome         Windows     False        desktop    Southeast Asia
# 1  Chrome       Macintosh     False        desktop    Eastern Europe
# 2  Chrome       Macintosh     False        desktop     South America
# 3  Safari             iOS      True         mobile  Northern America
# 4  Safari             iOS      True         mobile  Northern America
#
#      source     medium isTrueDirect hits pageviews bounces newVisits  \
# 0    google    organic          NaN    1         1       1         1
# 1    google    organic          NaN    1         1       1         1
# 2  Partners  affiliate          NaN    1         1       1         1
# 3    google    organic         True    1         1       1       NaN
# 4    google    organic          NaN    5         4     NaN         1
#
#   transactionRevenue
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
diccionarios
# Out:
# ['device', 'geoNetwork', 'trafficSource', 'totals']

# %%
# Eliminar columnas
columnas_a_eliminar = ['device', 'geoNetwork', 'trafficSource', 'totals', 'sessionId', 'visitId']

df2 = df.drop(columnas_a_eliminar, axis=1)

# %%
df2.head()
# Out:
#   channelGrouping      date        fullVisitorId  socialEngagementType  \
# 0  Organic Search  20160902  9674781571160116268  Not Socially Engaged
# 1  Organic Search  20160902  8590648239310839049  Not Socially Engaged
# 2      Affiliates  20160902  9772828344252850532  Not Socially Engaged
# 3  Organic Search  20160902  1350700416054916432  Not Socially Engaged
# 4  Organic Search  20160902  1350700416054916432  Not Socially Engaged
#
#    visitNumber  visitStartTime
# 0            1      1472804607
# 1            1      1472835928
# 2            1      1472856802
# 3            2      1472879649
# 4            1      1472829671

# %%
# Concatenación a lo largo de las columnas
df3 = pd.concat([df2, df_traffic], axis=1)

# %%
df3.head()
# Out:
#   channelGrouping      date        fullVisitorId  socialEngagementType  \
# 0  Organic Search  20160902  9674781571160116268  Not Socially Engaged
# 1  Organic Search  20160902  8590648239310839049  Not Socially Engaged
# 2      Affiliates  20160902  9772828344252850532  Not Socially Engaged
# 3  Organic Search  20160902  1350700416054916432  Not Socially Engaged
# 4  Organic Search  20160902  1350700416054916432  Not Socially Engaged
#
#    visitNumber  visitStartTime browser operatingSystem  isMobile  \
# 0            1      1472804607  Chrome         Windows     False
# 1            1      1472835928  Chrome       Macintosh     False
# 2            1      1472856802  Chrome       Macintosh     False
# 3            2      1472879649  Safari             iOS      True
# 4            1      1472829671  Safari             iOS      True
#
#   deviceCategory      subContinent    source     medium isTrueDirect hits  \
# 0        desktop    Southeast Asia    google    organic          NaN    1
# 1        desktop    Eastern Europe    google    organic          NaN    1
# 2        desktop     South America  Partners  affiliate          NaN    1
# 3         mobile  Northern America    google    organic         True    1
# 4         mobile  Northern America    google    organic          NaN    5
#
#   pageviews bounces newVisits transactionRevenue
# 0         1       1         1                NaN
# 1         1       1         1                NaN
# 2         1       1         1                NaN
# 3         1       1       NaN                NaN
# 4         4     NaN         1                NaN

# %%
# Nombres
nuevos_nombres = {
    'channelGrouping': 'agrupacion_canal',
    'date': 'fecha',
    'fullVisitorId': 'id_visitante_completo',
    'socialEngagementType': 'tipo_interaccion_social',
    'visitNumber': 'numero_visita',
    'visitStartTime': 'hora_inicio_visita',
    'browser': 'navegador',
    'operatingSystem': 'sistema_operativo',
    'isMobile': 'es_movil',
    'deviceCategory': 'categoria_dispositivo',
    'subContinent': 'subcontinente',
    'source': 'fuente',
    'medium': 'medio',
    'isTrueDirect': 'es_directo_verdadero',
    'hits': 'visitas',
    'pageviews': 'paginas_vistas',
    'bounces': 'rebotes',
    'newVisits': 'nuevas_visitas',
    'transactionRevenue': 'ingresos_transaccion'
}


# nombres de las columnas
df3.rename(columns=nuevos_nombres, inplace=True)

# %%
df3.head()
# Out:
#   agrupacion_canal     fecha  id_visitante_completo tipo_interaccion_social  \
# 0   Organic Search  20160902    9674781571160116268    Not Socially Engaged
# 1   Organic Search  20160902    8590648239310839049    Not Socially Engaged
# 2       Affiliates  20160902    9772828344252850532    Not Socially Engaged
# 3   Organic Search  20160902    1350700416054916432    Not Socially Engaged
# 4   Organic Search  20160902    1350700416054916432    Not Socially Engaged
#
#    numero_visita  hora_inicio_visita navegador sistema_operativo  es_movil  \
# 0              1          1472804607    Chrome           Windows     False
# 1              1          1472835928    Chrome         Macintosh     False
# 2              1          1472856802    Chrome         Macintosh     False
# 3              2          1472879649    Safari               iOS      True
# 4              1          1472829671    Safari               iOS      True
#
#   categoria_dispositivo     subcontinente    fuente      medio  \
# 0               desktop    Southeast Asia    google    organic
# 1               desktop    Eastern Europe    google    organic
# 2               desktop     South America  Partners  affiliate
# 3                mobile  Northern America    google    organic
# 4                mobile  Northern America    google    organic
#
#   es_directo_verdadero visitas paginas_vistas rebotes nuevas_visitas  \
# 0                  NaN       1              1       1              1
# 1                  NaN       1              1       1              1
# 2                  NaN       1              1       1              1
# 3                 True       1              1       1            NaN
# 4                  NaN       5              4     NaN              1
#
#   ingresos_transaccion
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
df3['fecha'] = pd.to_datetime(df3['fecha'], format='%Y%m%d')

# %%
# Convertir la marca de tiempo Unix a datetime
df3['hora_inicio_visita'] = pd.to_datetime(df3['hora_inicio_visita'], unit='s')

# %%
df3.tail()
# Out:
#       agrupacion_canal      fecha  id_visitante_completo  \
# 12278           Social 2017-01-04    7330357551242339916
# 12279           Social 2017-01-04     696320405243257438
# 12280           Social 2017-01-04    5437703324867866371
# 12281           Social 2017-01-04    8869363093179043393
# 12282           Social 2017-01-04    2905034275926274980
#
#       tipo_interaccion_social  numero_visita  hora_inicio_visita  \
# 12278    Not Socially Engaged              1 2017-01-04 14:36:48
# 12279    Not Socially Engaged              1 2017-01-05 01:40:07
# 12280    Not Socially Engaged              1 2017-01-05 04:55:22
# 12281    Not Socially Engaged              2 2017-01-05 07:38:47
# 12282    Not Socially Engaged              1 2017-01-05 05:22:17
#
#              navegador sistema_operativo  es_movil categoria_dispositivo  \
# 12278           Chrome           Windows     False               desktop
# 12279           Chrome           Android      True                mobile
# 12280           Chrome             Linux     False               desktop
# 12281           Chrome           Android      True                mobile
# 12282  Android Webview           Android      True                tablet
#
#          subcontinente       fuente     medio es_directo_verdadero visitas  \
# 12278   Eastern Europe  youtube.com  referral                  NaN       1
# 12279   Western Europe  youtube.com  referral                  NaN       1
# 12280    Southern Asia  youtube.com  referral                  NaN       1
# 12281  Northern Europe  youtube.com  referral                 True       2
# 12282  Southern Africa  youtube.com  referral                  NaN       3
#
#       paginas_vistas rebotes nuevas_visitas ingresos_transaccion
# 12278              1       1              1                  NaN
# 12279              1       1              1                  NaN
# 12280              1       1              1                  NaN
# 12281              2     NaN            NaN                  NaN
# 12282              3     NaN              1                  NaN

# %%
# Crear la columna de mes
df3['mes'] = df3['hora_inicio_visita'].dt.month

# Crear la columna de día
df3['dia'] = df3['hora_inicio_visita'].dt.day

# Crear la columna de año
df3['año'] = df3['hora_inicio_visita'].dt.year

# Crear la columna de hora
df3['hora'] = df3['hora_inicio_visita'].dt.hour

# %%
df3.head()
# Out:
#   agrupacion_canal      fecha  id_visitante_completo tipo_interaccion_social  \
# 0   Organic Search 2016-09-02    9674781571160116268    Not Socially Engaged
# 1   Organic Search 2016-09-02    8590648239310839049    Not Socially Engaged
# 2       Affiliates 2016-09-02    9772828344252850532    Not Socially Engaged
# 3   Organic Search 2016-09-02    1350700416054916432    Not Socially Engaged
# 4   Organic Search 2016-09-02    1350700416054916432    Not Socially Engaged
#
#    numero_visita  hora_inicio_visita navegador sistema_operativo  es_movil  \
# 0              1 2016-09-02 08:23:27    Chrome           Windows     False
# 1              1 2016-09-02 17:05:28    Chrome         Macintosh     False
# 2              1 2016-09-02 22:53:22    Chrome         Macintosh     False
# 3              2 2016-09-03 05:14:09    Safari               iOS      True
# 4              1 2016-09-02 15:21:11    Safari               iOS      True
#
#   categoria_dispositivo     subcontinente    fuente      medio  \
# 0               desktop    Southeast Asia    google    organic
# 1               desktop    Eastern Europe    google    organic
# 2               desktop     South America  Partners  affiliate
# 3                mobile  Northern America    google    organic
# 4                mobile  Northern America    google    organic
#
#   es_directo_verdadero visitas paginas_vistas rebotes nuevas_visitas  \
# 0                  NaN       1              1       1              1
# 1                  NaN       1              1       1              1
# 2                  NaN       1              1       1              1
# 3                 True       1              1       1            NaN
# 4                  NaN       5              4     NaN              1
#
#   ingresos_transaccion  mes  dia   año  hora
# 0                  NaN    9    2  2016     8
# 1                  NaN    9    2  2016    17
# 2                  NaN    9    2  2016    22
# 3                  NaN    9    3  2016     5
# 4                  NaN    9    2  2016    15

# %%
df3['hora'].unique()
# Out:
# array([ 8, 17, 22,  5, 15, 14, 16,  6, 10, 19, 12,  2,  3,  9, 18,  4, 13,
#        21,  1, 11, 20, 23,  7,  0])

# %%
# Definir una función para asignar etiquetas basadas en la hora
def asignar_periodo(hora):
    if 6 <= hora < 12:
        return 'mañana'
    elif 12 <= hora < 18:
        return 'tarde'
    elif 18 <= hora < 24:
        return 'noche'
    else:
        return 'madrugada'


# Crear una nueva columna 'periodo' aplicando la función a la columna 'hora'
df3['periodo'] = df3['hora'].apply(asignar_periodo)

# %%
df3.head()
# Out:
#   agrupacion_canal      fecha  id_visitante_completo tipo_interaccion_social  \
# 0   Organic Search 2016-09-02    9674781571160116268    Not Socially Engaged
# 1   Organic Search 2016-09-02    8590648239310839049    Not Socially Engaged
# 2       Affiliates 2016-09-02    9772828344252850532    Not Socially Engaged
# 3   Organic Search 2016-09-02    1350700416054916432    Not Socially Engaged
# 4   Organic Search 2016-09-02    1350700416054916432    Not Socially Engaged
#
#    numero_visita  hora_inicio_visita navegador sistema_operativo  es_movil  \
# 0              1 2016-09-02 08:23:27    Chrome           Windows     False
# 1              1 2016-09-02 17:05:28    Chrome         Macintosh     False
# 2              1 2016-09-02 22:53:22    Chrome         Macintosh     False
# 3              2 2016-09-03 05:14:09    Safari               iOS      True
# 4              1 2016-09-02 15:21:11    Safari               iOS      True
#
#   categoria_dispositivo     subcontinente    fuente      medio  \
# 0               desktop    Southeast Asia    google    organic
# 1               desktop    Eastern Europe    google    organic
# 2               desktop     South America  Partners  affiliate
# 3                mobile  Northern America    google    organic
# 4                mobile  Northern America    google    organic
#
#   es_directo_verdadero visitas paginas_vistas rebotes nuevas_visitas  \
# 0                  NaN       1              1       1              1
# 1                  NaN       1              1       1              1
# 2                  NaN       1              1       1              1
# 3                 True       1              1       1            NaN
# 4                  NaN       5              4     NaN              1
#
#   ingresos_transaccion  mes  dia   año  hora    periodo
# 0                  NaN    9    2  2016     8     mañana
# 1                  NaN    9    2  2016    17      tarde
# 2                  NaN    9    2  2016    22      noche
# 3                  NaN    9    3  2016     5  madrugada
# 4                  NaN    9    2  2016    15      tarde

# %%
df3['dia'].unique()
# Out:
# array([ 2,  3, 26, 27, 23, 24, 12, 13,  4, 11, 14, 19, 18, 10, 21, 22,  1,
#        30, 20, 25, 15, 29, 16, 31, 28,  9, 17,  5,  6,  8,  7])

# %%
# Crear una nueva columna 'dia_semana' que contenga el nombre del día de la semana
df3['dia_semana'] = df3['hora_inicio_visita'].dt.strftime('%A')

# %%
df3.head()
# Out:
#   agrupacion_canal      fecha  id_visitante_completo tipo_interaccion_social  \
# 0   Organic Search 2016-09-02    9674781571160116268    Not Socially Engaged
# 1   Organic Search 2016-09-02    8590648239310839049    Not Socially Engaged
# 2       Affiliates 2016-09-02    9772828344252850532    Not Socially Engaged
# 3   Organic Search 2016-09-02    1350700416054916432    Not Socially Engaged
# 4   Organic Search 2016-09-02    1350700416054916432    Not Socially Engaged
#
#    numero_visita  hora_inicio_visita navegador sistema_operativo  es_movil  \
# 0              1 2016-09-02 08:23:27    Chrome           Windows     False
# 1              1 2016-09-02 17:05:28    Chrome         Macintosh     False
# 2              1 2016-09-02 22:53:22    Chrome         Macintosh     False
# 3              2 2016-09-03 05:14:09    Safari               iOS      True
# 4              1 2016-09-02 15:21:11    Safari               iOS      True
#
#   categoria_dispositivo     subcontinente    fuente      medio  \
# 0               desktop    Southeast Asia    google    organic
# 1               desktop    Eastern Europe    google    organic
# 2               desktop     South America  Partners  affiliate
# 3                mobile  Northern America    google    organic
# 4                mobile  Northern America    google    organic
#
#   es_directo_verdadero visitas paginas_vistas rebotes nuevas_visitas  \
# 0                  NaN       1              1       1              1
# 1                  NaN       1              1       1              1
# 2                  NaN       1              1       1              1
# 3                 True       1              1       1            NaN
# 4                  NaN       5              4     NaN              1
#
#   ingresos_transaccion  mes  dia   año  hora    periodo dia_semana
# 0                  NaN    9    2  2016     8     mañana     Friday
# 1                  NaN    9    2  2016    17      tarde     Friday
# 2                  NaN    9    2  2016    22      noche     Friday
# 3                  NaN    9    3  2016     5  madrugada   Saturday
# 4                  NaN    9    2  2016    15      tarde     Friday

# %%
df3['dia_semana'].unique()
# Out:
# array(['Friday', 'Saturday', 'Thursday', 'Sunday', 'Monday', 'Wednesday',
#        'Tuesday'], dtype=object)

# %%
# Eliminar columnas
columnas_a_eliminar = ['fecha', 'id_visitante_completo', 'hora_inicio_visita', 'dia', 'año', 'hora', 'tipo_interaccion_social']

df4 = df3.drop(columnas_a_eliminar, axis=1)

# %%
df4.head()
# Out:
#   agrupacion_canal  numero_visita navegador sistema_operativo  es_movil  \
# 0   Organic Search              1    Chrome           Windows     False
# 1   Organic Search              1    Chrome         Macintosh     False
# 2       Affiliates              1    Chrome         Macintosh     False
# 3   Organic Search              2    Safari               iOS      True
# 4   Organic Search              1    Safari               iOS      True
#
#   categoria_dispositivo     subcontinente    fuente      medio  \
# 0               desktop    Southeast Asia    google    organic
# 1               desktop    Eastern Europe    google    organic
# 2               desktop     South America  Partners  affiliate
# 3                mobile  Northern America    google    organic
# 4                mobile  Northern America    google    organic
#
#   es_directo_verdadero visitas paginas_vistas rebotes nuevas_visitas  \
# 0                  NaN       1              1       1              1
# 1                  NaN       1              1       1              1
# 2                  NaN       1              1       1              1
# 3                 True       1              1       1            NaN
# 4                  NaN       5              4     NaN              1
#
#   ingresos_transaccion  mes    periodo dia_semana
# 0                  NaN    9     mañana     Friday
# 1                  NaN    9      tarde     Friday
# 2                  NaN    9      noche     Friday
# 3                  NaN    9  madrugada   Saturday
# 4                  NaN    9      tarde     Friday

# %%
import pandas as pd


df4.rename(columns={
    'agrupacion_canal': 'grupo_canal',
    'tipo_interaccion_social': 'tipo_interaccion_social',
    'numero_visita': 'cantidad_visitas',
    'navegador': 'navegador',
    'sistema_operativo': 'sistema_operativo',
    'es_movil': 'es_movil',
    'categoria_dispositivo': 'categoria_dispositivo',
    'subcontinente': 'subcontinente',
    'fuente': 'fuente_trafico',
    'medio': 'medio_trafico',
    'es_directo_verdadero': 'es_directo',
    'visitas': 'cantidad_visitas',
    'paginas_vistas': 'paginas_vistas',
    'rebotes': 'rebotes',
    'nuevas_visitas': 'nuevas_visitas',
    'ingresos_transaccion': 'ingresos_transaccion',
    'mes': 'mes',
    'periodo': 'periodo_del_dia',
    'dia_semana': 'dia_semana'
}, inplace=True)

# %%
columna_a_mover = 'ingresos_transaccion'

# Guarda la columna en una variable temporal
columna_temporal = df4[columna_a_mover]

# Elimina la columna de su posición original
df4.drop(columns=[columna_a_mover], inplace=True)

# Inserta la columna al principio del DataFrame
df4.insert(0, columna_a_mover, columna_temporal)

# %%
df4.head()
# Out:
#   ingresos_transaccion     grupo_canal cantidad_visitas navegador  \
# 0                  NaN  Organic Search                1    Chrome
# 1                  NaN  Organic Search                1    Chrome
# 2                  NaN      Affiliates                1    Chrome
# 3                  NaN  Organic Search                2    Safari
# 4                  NaN  Organic Search                1    Safari
#
#   sistema_operativo  es_movil categoria_dispositivo     subcontinente  \
# 0           Windows     False               desktop    Southeast Asia
# 1         Macintosh     False               desktop    Eastern Europe
# 2         Macintosh     False               desktop     South America
# 3               iOS      True                mobile  Northern America
# 4               iOS      True                mobile  Northern America
#
#   fuente_trafico medio_trafico es_directo cantidad_visitas paginas_vistas  \
# 0         google       organic        NaN                1              1
# 1         google       organic        NaN                1              1
# 2       Partners     affiliate        NaN                1              1
# 3         google       organic       True                1              1
# 4         google       organic        NaN                5              4
#
#   rebotes nuevas_visitas  mes periodo_del_dia dia_semana
# 0       1              1    9          mañana     Friday
# 1       1              1    9           tarde     Friday
# 2       1              1    9           noche     Friday
# 3       1            NaN    9       madrugada   Saturday
# 4     NaN              1    9           tarde     Friday

# %%
df4['ingresos_transaccion'].value_counts()
# Out:
# 13590000     3
# 19190000     3
# 33590000     3
# 31490000     2
# 69990000     2
#             ..
# 22490000     1
# 74850000     1
# 32490000     1
# 239880000    1
# 25240000     1
# Name: ingresos_transaccion, Length: 146, dtype: int64

# %%
import missingno as msno

# msno.matrix para visualizar los valores nulos
msno.matrix(df4)
# Out:
# <Axes: >

# %%
df4['es_directo'].fillna(False, inplace=True)
df4['rebotes'].fillna(0, inplace=True)
df4['nuevas_visitas'].fillna(0, inplace=True)
df4['ingresos_transaccion'].fillna(0, inplace=True)

# %%
msno.matrix(df4)
# Out:
# <Axes: >

# %%
df4.to_csv('PrediccionGasto.csv', index=False)

# %%
df4['ingresos_transaccion'].value_counts()
# Out:
# 0           12119
# 13590000        3
# 33590000        3
# 19190000        3
# 27190000        2
#             ...
# 24730000        1
# 6990000         1
# 14480000        1
# 95180000        1
# 25240000        1
# Name: ingresos_transaccion, Length: 147, dtype: int64
